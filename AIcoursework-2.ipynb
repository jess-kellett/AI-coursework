# %%
import csv
import string
import re

def loading_reviews(clothing_reviews, limit=400):
  '''
  This function reads a CVS file containing clothing reviews, taking the csv file
  and the number of reviews to be classified as parameters.
  It then creates a list of dictionary containing the review and the reviews label
  (positive if the ratings 4 or above and negative if it is 2 or less.)
  The function returns the list of dictionaries.
  '''
  reviews = []
  with open(clothing_reviews, 'r') as reviews_file:
    reader = csv.DictReader(reviews_file)
    for row in reader:
      if len(reviews) >= limit:
        break
      rating = int(row["Rating"])
      if rating >= 4:
        label = "positive"
      elif rating <= 2:
        label = "negative"
      # Skips rating 3 - ambiguous reviews could be positive or negaive so
      # including them would make evaluation unfair and reduce the classifiers reliablity
      else:
        continue
      review_text = row["Review Text"]
      if not review_text or not review_text.strip():
        continue
      reviews.append({
          "review" : row["Review Text"],
          "label" : label
          })
  return reviews

def preprocess_cleaning_reviews(reviews_list):
  """
  This function takes a list of dictionaries containing reviews and their labels
  as a parameter. The function then sorts through this list and cleans it.
  This includes making it all lowercase, removing punctuation and removing stop words.
  It returns the cleaned reviews as another list of dictionaries.
  """
  cleaned_reviews = []
  for reviews in reviews_list:
    # All reviews are converted into lowercase and all puntuation is removed to
    # ensure the same word is treated in the same way and matches the keywords.
    review_text = reviews["review"].lower().translate(str.maketrans('', '', string.punctuation))
    # stopwords are common words that add no sentiment value
    # they have been removed to help focus the classifier on meaningful words.
    stop_words = {"the", "a", "an", "is", "was", "and", "to", "of", "it", "this", "i", "has", "have", "its", "in", "im", "on", "am", "get", "my", "but", "as", "be", "so", "with"}
    words_in_reviews = review_text.split()
    words_in_reviews = [word for word in words_in_reviews if word not in stop_words]
    cleaned_reviews.append({"review": " ".join(words_in_reviews),
                           "label": reviews["label"]})
  return cleaned_reviews

def classifying_reviews(cleaned_review):
  """
  The parameter of this function is a string containing the cleaned review. This
  function classifies each review into either positive, negative or neutral
  depending on how many positive or negative keywords are present. It handles
  negation of both the positive and negative keywords to increase accuracy. It
  returns the classification outcome - "positive", "negative" or "neutral".
  """

  # Regex patterns are used to catch word variants.
  positive_keywords = ["wonderful", "sexy", r"comfortabl\w*", r"love\w*", "pretty", "glad", "fun", r"flirt\w*", r"fabulous\w*", "great", r"compliment\w*", r"flatter\w*", r"perfect\w*", r"gorgeous\w*", r"nice\w*", "feminine", r"beautiful\w*", "cute", "soft", "unique", "cozy", "better"]
  negative_keywords = [r"bad\w*", "unflattering", r"uncomfortable\w*", r"return\w*", "hate", "cheap", "awkward", r"disappoint\w*", r"itch\w*", "zero support", "seethrough"]
  negation_words = {"not", "never", "no", "doesnt", "wont", "dont"}
  override_negatives = [r"return\w*", r"refund\w*", "sending back"]

  review_words = cleaned_review.split()
  positive_count = 0
  negative_count = 0
  for index, words in enumerate(review_words):
    # Override checks occurs first as customers who have returned items have
    # overall disliked the product no matter how many positive attributes they have mentioned.
    for pattern in override_negatives:
      if re.search(pattern, words):
        return "negative"
    for pattern in positive_keywords:
      if re.search(pattern, words):
        # the word before the keyword is always checked to ensure it is not a
        # negation word, which would change the meaning and label completely.
        if index > 0 and review_words[index - 1] in negation_words:
          negative_count += 1
        else:
          positive_count += 1
    for pattern in negative_keywords:
      if re.search(pattern, words):
        if index > 0 and review_words[index - 1] in negation_words:
          positive_count += 1
        else:
          negative_count += 1
  if positive_count > negative_count:
    return "positive"
  elif positive_count < negative_count:
    return "negative"
  else:
    return "neutral"

def evaluate(cleaned_reviews):
  """
  This function recieves the list of dictionaries containing the cleaned reviews
  and their corresponding labels. It compares the labels of each review with the
  predicted classifations and returns the accuracy of the classifier, total reviews
  and total correctly classified reviews.
  """

  correctly_classified = 0
  total_reviews = 0

  for review in cleaned_reviews:
    review_text = review["review"]
    true_label = review["label"]

    predicted_by_algorithm = classifying_reviews(review_text)

    if predicted_by_algorithm == true_label:
      correctly_classified += 1

    if predicted_by_algorithm != true_label:
      print(f"Incorrect - Predicted: {predicted_by_algorithm}, Actual: {true_label}")
      print(f"Review: {review_text}\n")


    total_reviews += 1

  accuracy = correctly_classified / total_reviews
  return accuracy, total_reviews, correctly_classified


reviews = loading_reviews("clothing_reviews.csv")
cleaned_reviews = preprocess_cleaning_reviews(reviews)

accuracy, total_reviews, correctly_classified = evaluate(cleaned_reviews)

print(f"Accuracy: " + str(accuracy))
print(f"Total Reviews: " + str(total_reviews))
print(f"Correctly Classified: " + str(correctly_classified))
# Out:
# Incorrect - Predicted: positive, Actual: negative
# Review: been waiting for sweater coat ship for weeks excited for arrive coat not true size made me look short squat sleeves are very wide although long light weight fall coat sleeves dont need wide because you wouldnt layerng too much underneath buttons need moved at least three inches for nicer fit thought about redoing buttons myself sleeves looked even more out proportion tigh
#
# Incorrect - Predicted: negative, Actual: positive
# Review: nice top armholes are bit oversized older woman picky about that print pretty unusual just didnt look great me theres slight peplum back that hangs nicely lightweight tee fabric thats opaque tried black bra which barely visible great for warmer climates there are many gorgeous tops out now that decided return since summer winding down do recommend
#
# Incorrect - Predicted: negative, Actual: positive
# Review: got petite length size o fit just right like that didnt altered length can wear flats plenty clearance floor from bottom hem only beef design height waist personally think that elastic waistband looks cheap really needs concealed belt yet because sits high literally right under bustline tricky one pull off wide belt that sort does th
#
# Incorrect - Predicted: positive, Actual: negative
# Review: why do designers keep making crop tops cant imagine would flattering anyone especially someone average height well endowed top looked like football player pattern fabric are gorgeous if you are like 4 tall super tiny can fit xxs may work between 68 fit small huge me almost bigger at bottom than top such weird cut there cami underneath if rides up that will show that 80s
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: short torso works well for me 34c bought 0 theres not much stretch fabric fitted chest not uncomfortable way definitely doesnt hang extra fabric like model zipper goes almost all way down bottom easier off which makes up for lack stretch n fabric unlike another reviewer found went really well navy pants wore business meeting under blazer wi
#
# Incorrect - Predicted: negative, Actual: positive
# Review: would loved dress if bust waist were just little more fitted 32c top too big fit perfectly hips lace material means cannot easily altered chose return dress would definitely kept if were better fit
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: zipper broke piece first time wore very disappointing since love design actually going try replace zipper myself something stronger annoying that come that
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: really hoping like did not look way does model at least not me sharkbite hem much more pronounced looser one photo looks like pinned back 58 usually wear medium or large got medium there lot more material bottom half than photo shows made me look bigger not flattering material nice weave thin delicate bought holly deep olive blue colors
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: tried from sale section they only had 2 usually do 0 surprisingly that size right fit fitted just enough room eat te blue light blue almost neutral white embroidery think looked stylish decided keep peplum part hit just right spot short petite torso normal size
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: usually wear medium bought small fit ok had no shape not flattering love baby doll dresses tops tent daughter saw me try said thats piece tablecloth going back
#
# Incorrect - Predicted: positive, Actual: negative
# Review: very excited order top red xs cute huge shapeless support thin had go back shouldve looked at other reviews
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: fabric felt cheap didnt find flattering top for reference wearing medium photos measurements are 383040
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: runs big looked unflattering petite might work someone taller
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: bought lovely silkvelvet shirt quotskyquot color more teal blue side than sky blue which disappointed me definitely darker than appears photo still luxurious wellmade beauty sassy appeal drapes like snake slithering down your body comes attitude
#
# Incorrect - Predicted: negative, Actual: positive
# Review: excited order beautiful shirt color sky gorgeous another reviewer saidit runs small also way too short sadly will returning gave 5 stars because beautiful great qualityit just didnt fit me
#
# Incorrect - Predicted: positive, Actual: negative
# Review: designshape dress are quite flattering flirty feminine there no way that dress received new color faded washed out red there are black stains all over belt area there no tag fabric looks droopy laundered not crisp stiff or new very disappointed by quality item that received undoubtedly one going back dear retailer please make sure that you do not send preowend clothing articles
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: prior reviewer nailed summary dress definitely needs heels 54 120 34d size 36 usually wear size s or 4 most retailer stuff
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: top super comfy casual slitdesign front gives more stylish look than your average white long sleeve tee would definitely recommend
#
# Incorrect - Predicted: negative, Actual: positive
# Review: obsessed peplum down coats because ones you usually see no shape are extremely unflattering excited for arrive quite nice looks more feminine than other down coats out there coat itself runs just true shirt size not what want for coat will returning for size up because will want wear sweater or at least maybe thicker shirt under especially for winter or fall fabric decent weigh
#
# Incorrect - Predicted: positive, Actual: negative
# Review: online looks like great sweater ordered xxsp found that sweater much wider middle than pictured fact pretty sure they pinned shirt back for picture make appear slimmer unfortunately sweater will not work for me hourglass shape shirt makes me look 20 pounds heavier
#
# Incorrect - Predicted: positive, Actual: negative
# Review: worried about item when ordered because how looks picture had wishful thinking should gone gut shirt does not same quality all other retailer purchases seethrough flimsy bottom just like picture hangs odd rumpled way top very flattering though shame if bottom fit nicer like their other products could gotten away wearing cami under make up for qu
#
# Incorrect - Predicted: negative, Actual: positive
# Review: gorgeous top very nice detail work soft flattering dont think too full bottom at all mine loose pretty straight silhouette word warning soft pink not pink peach some pink definitely not color if peach isnt flattering you heed other reviewers comments they are weighing correctly will either return for white or dye fabric myself more flattering shade bummer that thought other reviewers might
#
# Incorrect - Predicted: negative, Actual: positive
# Review: excited about arrival maza dress much surprise material not structured thought would from photos fit very tight did not fall nicely anticipated because loved classic design decided give another chance returned for next size up fell love open sleeve nice surprise touch if elegance front buttons added bit old charm feminine appeal while material not v
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: ranna designs richly detailed dresses no exception looks just like pictures colorscutdrape exception modesty hook at deep vneck sleeves are sheer elastic cuff dress does not stretchthe bodice felt very fitted tight especially at waist band runs tts or small if youre bustybroad shouldered size up dreadful side zip fully lined all synthetic fabric boo purchased size 10p stats 36c382735135
#
# Incorrect - Predicted: positive, Actual: negative
# Review: bought large could barely pull up over butt runs extremely small cute if your not stick figure not suit for you
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: dress makes you feel like bohemian goddess falls right area absolutely adorable dress very fragile handle care
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: new favorite top looks fits described
#
# Incorrect - Predicted: positive, Actual: negative
# Review: similar pair capris from retailer when ordered these thought they were same different color these are less flattering may not keep them
#
# Incorrect - Predicted: positive, Actual: negative
# Review: loved dress from moment tried flattering postpartum body without being huge tent soft fabric for whitelightly striped dress not sheer bummed because after washing only twice followed instructions wash gentle cycle low tumble dry holes started appearing everywhere both cream ribbed hem front bottom all across chest white part fabric only looks like black stripes are holding holes toget
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: per other reviewers sized up from small medium jacket fits me just right room for layers short cropped like where hits me versatile for jeans dresses
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: like other reviewer said top extremely wide boxy must pinned picture online very frustrating when they do that thank goodness didnt pay for shipping for reference 52 135 pounds bought xxs going back for sure trying lose baby weight not trying look pregnant
#
# Incorrect - Predicted: positive, Actual: negative
# Review: wanted love sweatshirt alas going back upon opening unfolding first thing noticed dots not solid they are sort distressed looking parts them missing secondly doesnt lot structure soft kind floppy weird way just not flattering me looks more like pajama top than something would wear out house for reference ordered 3 usually 1012 tops
#
# Incorrect - Predicted: negative, Actual: positive
# Review: been searching for perfect denim jacket love darker color more modern day less 80s runs little small always either s or xs at retailer lately their clothes seem running little bigger been xs most tops when order online never know which size ordered xs however very tight arms across shoulders wanted able roll sleeves up returned for s fits great
#
# Incorrect - Predicted: negative, Actual: positive
# Review: first ordered m normally 810 m too small returned ordered lg lg fits great there huge area distressing shoulder that will turn into hole love jacket cannot keep condition hopefully will make store soon there are none win hour me look before buy
#
# Incorrect - Predicted: positive, Actual: negative
# Review: like another reviewer mentioned shirt way too short only 52 xs there no way top would tuck like model also quality isnt great very thin there are strings hanging from some seams front shame bc print really pretty there cute little bicycle charm tag which makes feel more unique sadly going back
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: dress potential didnt work for me runs true size little big ordered medium usual size for maeve for length fit me model 59 reason not keeping that wish had some darts back help define waist bit
#
# Incorrect - Predicted: positive, Actual: negative
# Review: top way too short only 51 way too wide cut top wide looked like tent me really wanted love top because material style sleeves ruffle are beautiful unfortunately there something wrong cut ive several blouses made by one fine day which fit nicely for some reason top did not ordered usual s size even going xs would not work because cut wrong
#
# Incorrect - Predicted: positive, Actual: negative
# Review: blouse beautiful collar sleeves materialeverything except cut like tent needed more tapered which would easy do while still maintaining beautiful breezy flow about two inches longer had been drooling over top for awhile disappointed please fix then will buy again 54 140lbs bustya small perfect exception massive amount material
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: not coat by any means merely thin wool boucle like sweater cheap thin synthetic lining also would never want lining seen by anyone if were set sweater chair or helped putting thing length bulk hard layer under anything else isnt pretty enough for spring coatsizing also 2 sizes larger than anticipated
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: not sure why shirt getting bad reviews tall long torso perhaps that issue for some who find not flattering maybe if your taller hangs better say love everything about fantastic print very flowy dont think too much that regard think fitting romantic girly style garment opinion not too short just right took medium 58 athletic
#
# Incorrect - Predicted: negative, Actual: positive
# Review: tried other day at local store size xss although wool didnt notice that itchy usually wool bothers me small build did like long oversized look admit drawn print anyways noticed right armhole larger than left tried another xss same probably armholes will smaller petite sizes decided make other purchases will order petite xss few wks since invent
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: great drape length pattern super versatile solids or prints finding wool itchy around neck not sure if will keep though dont seem want take off lightweight boiled wool texture contrasting print design cool
#
# Incorrect - Predicted: positive, Actual: negative
# Review: skirt very short ordered usual xs petite short that longest part ended above ankle thats quite off because only 5 feet tall wore pretty low hips also flares out awkwardly below knee there are 2 vertical seems they exacerbate jagged appearance hem drawn edgy style shown photo person looks like 5 year old cut up skirt plus fabricwhile thick beautiful stretchyhas
#
# Incorrect - Predicted: positive, Actual: negative
# Review: got top wear shorts color goes lot different prints quality excellent top runs very large three 3 sizes too large for record 342535 ordered regular size xs top makes me like pregnant twins also layering looks nothing like does model looks sloppy unkept general think would still great for ladies who are bigger chest waist otherwise just doesnt wor
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: able snatch dress up just before sold out see now back stock quality fabrics outstanding not flimsy at all top stretchy normally would wear 2 at retailer only choice had 0 fit 55 tall 125 lbs everything about dress makes me smile cant wait wear holiday party dont hesitate if you are fence
#
# Incorrect - Predicted: neutral, Actual: positive
# Review: got he green color gray accent stitching looks awesome gray tone leggings super soft definitely runs little big 56 140 lbs ordered small not unflattering way
#
# Incorrect - Predicted: positive, Actual: negative
# Review: love byron lars dresses design onpoint ruffle at neckline pretty dress fits like dream however fabric would loved if dress had heavier feel sadly going back today
#
# Incorrect - Predicted: negative, Actual: positive
# Review: happened upon local store despite fact that online exclusive love finding returns can see them person loved soft colors right away hesitation standup collar actually folds down just fine gives vest lapels too also looks nice belted left slightly open usually wear small or xs tops small fits nicely doesnt need close since there are no builtin fasteners will wear long button down shirt o
#
# Incorrect - Predicted: negative, Actual: positive
# Review: really like top super cute perfect for football game or fairly casual event material ribbed thick enough that you cant see through purchased top red initially petite ended up returning for regular size love top
#
# Incorrect - Predicted: neutral, Actual: negative
# Review: three strikes retailer out for me disappointed really liked dress looking for fun distinctive new shift dress got tried took off went back look at listing onlinenowhere does mention that dropseam shoulders guess you can see if you zoom closely image not mentioned text who gods green earth actually looks good dropshoulder hits every woman under 510 right middl
#
# Accuracy: 0.875
# Total Reviews: 400
# Correctly Classified: 350

# %%
# -------- Test section --------
# This section tests my classifier against 6 different edge cases to ensure the system behaves as expected.
# When running this section, please run my main code first.

print("---- Test cases ----")

test_cases = [
    {
        "title": "Test case 1: Clear positive review",
        "review": "I love this dress. It was super comfortable and the pattern was lovely. The design is so fun and pretty. I'm super glad I ordered it.",
        "expected_label": "positive"
    },
    {
        "title": "Test case 2: Clear negative review",
        "review": "I hate this dress. It was super uncomfortable and the pattern looks cheap and seethrough. The material is very itchy, I'm really disappointed.",
        "expected_label": "negative"
    },
    {
        "title": "Test case 3: Negation handling",
        "review": "This dress was not comfortable and not pretty",
        "expected_label": "negative"
    },
    {
        "title": "Test case 4: Override case - returned item",
        "review": "As much as I loved this dress and the pattern was fun, it didnt fit perfectly so I had to return it",
        "expected_label": "negative"
    },
    {
        "title": "Test case 5: Equally mixed review",
        "review": "I love this dress yet it is itchy",
        "expected_label": "neutral"
    },
    {
        "title": "Test case 6: No keywords",
        "review": "I ordered this dress for a special occasion",
        "expected_label": "neutral"
    }
  ]

passed = 0
for test in test_cases:
  cleaned_test_reviews = preprocess_cleaning_reviews([{"review": test["review"], "label": "positive"}])
  predicted_label = classifying_reviews(cleaned_test_reviews[0]["review"])
  result = "Passed" if predicted_label == test["expected_label"] else "Failed"
  if predicted_label == test["expected_label"]:
    passed += 1
  print(f"{test['title']} \nReview: {test['review']} \nExpected: {test['expected_label']} \nPredicted: {predicted_label} \nResult: {result} \n")

print(f"Passed: {passed}/{len(test_cases)}")
# Out:
# ---- Test cases ----
# Test case 1: Clear positive review
# Review: I love this dress. It was super comfortable and the pattern was lovely. The design is so fun and pretty. I'm super glad I ordered it.
# Expected: positive
# Predicted: positive
# Result: Passed
#
# Test case 2: Clear negative review
# Review: I hate this dress. It was super uncomfortable and the pattern looks cheap and seethrough. The material is very itchy, I'm really disappointed.
# Expected: negative
# Predicted: negative
# Result: Passed
#
# Test case 3: Negation handling
# Review: This dress was not comfortable and not pretty
# Expected: negative
# Predicted: negative
# Result: Passed
#
# Test case 4: Override case - returned item
# Review: As much as I loved this dress and the pattern was fun, it didnt fit perfectly so I had to return it
# Expected: negative
# Predicted: negative
# Result: Passed
#
# Test case 5: Equally mixed review
# Review: I love this dress yet it is itchy
# Expected: neutral
# Predicted: neutral
# Result: Passed
#
# Test case 6: No keywords
# Review: I ordered this dress for a special occasion
# Expected: neutral
# Predicted: neutral
# Result: Passed
#
# Passed: 6/6
